# %% [markdown]
# <a href="https://colab.research.google.com/github/jiedali/colab_temp/blob/main/breakout_run10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import time
import numpy as np
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
import gym
import random
from collections import deque
import matplotlib.pyplot as plt
# choose a GPU card
# os.environ['CUDA_VISIBLE_DEVICES']="0"
# Set seed for tensorflow
# SEED=123
# tf.set_random_seed(SEED)
# GYM_SEED=678
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri Nov 20 19:17:11 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    24W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
def preprocess(image):
    """ prepro 210x160x3 uint8 frame into 6400 (80x80) 2D float array """
    image = image[35:195] # crop
    image = image[::2,::2,0] # downsample by factor of 2
    image[image == 144] = 0 # erase background (background type 1)
    image[image == 109] = 0 # erase background (background type 2)
    image[image != 0] = 1 # everything else just set to 1
    return np.reshape(image.astype(np.float).ravel(), [80,80])

# %%
# set seed
SEED=1
tf.set_random_seed(SEED)
GYM_SEED=567
env = gym.make("Breakout-v0")
obs = env.reset()
env.seed(GYM_SEED)
# Out:
# [567, 2126561800]

# %%
# CNN for modeling the DQN
state_size=[80,80,1]
action_size=env.action_space.n
n_outputs=action_size
input_height=80
input_width=80
input_channels=1
# Initial learning rate for RMSprop
learning_rate=0.00025
rmsprop_decay= 0.99
rmsprop_constant = 1e-6
# # Use adam optimizer
# beta_1=0.9
# beta_2=0.999
# epsilon=1e-07
#
# Note that the action space is 4 with following meanings:
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT']
class DQN(object):
	def __init__(self, state_size, action_size, learning_rate, name='online_q_network'):
		self.state_size = state_size
		self.action_size = action_size
		self.learning_rate = learning_rate
		self.name = name

		with tf.variable_scope(name):
			with tf.name_scope("inputs"):
				# Jieda note: state is preprocessd 80*80*1 array
				self.inputs = tf.placeholder(tf.float32, [None, input_height, input_width, input_channels], name="inputs")

			with tf.name_scope("conv1"):
				self.conv1 = tf.layers.conv2d(
					inputs=self.inputs, filters=32, kernel_size=[8, 8], strides=4,
					kernel_initializer=tf.variance_scaling_initializer(),
					padding="VALID", use_bias=False, name='conv1')

				self.conv1_out = tf.nn.relu(self.conv1, name='conv1_out')

			with tf.name_scope("conv2"):
				self.conv2 = tf.layers.conv2d(
					inputs=self.conv1_out, filters=64,
					kernel_size=[4, 4], strides=2, padding="VALID",
					kernel_initializer=tf.variance_scaling_initializer(),
					use_bias=False, name='conv2')

				self.conv2_out = tf.nn.relu(self.conv2, name='conv2_out')

			with tf.name_scope("conv3"):
				self.conv3 = tf.layers.conv2d(
					inputs=self.conv2_out, filters=64,
					kernel_size=[3, 3], strides=1, padding="VALID",
					kernel_initializer=tf.variance_scaling_initializer(),
					name="conv3")

				self.conv3_out = tf.nn.relu(self.conv3, name='conv3_out')

			with tf.name_scope("flatten"):
				self.flatten = tf.contrib.layers.flatten(self.conv3_out)

			with tf.name_scope("fc1"):
				self.fc1 = tf.layers.dense(inputs=self.flatten,
				                           units=512, activation=tf.nn.relu,
				                           kernel_initializer=tf.variance_scaling_initializer(), name="fc1")

			with tf.name_scope("fc1"):
				self.fc2 = tf.layers.dense(inputs=self.flatten,
				                           units=512, activation=tf.nn.relu,
				                           kernel_initializer=tf.variance_scaling_initializer(), name="fc2")

			with tf.name_scope("outputs"):
				self.outputs = tf.layers.dense(inputs=self.fc2,
				                               units=action_size,
				                               kernel_initializer=tf.variance_scaling_initializer(),
				                               activation=None)
		# Output is the approximated Action Values Q(s,a), so we don't need any activation

	def get_outputs(self):
		return self.outputs

	def get_weights(self, scope_name):
		# give all the weights of that network
		trainable_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=scope_name)
		# create a dictionary to contain the values of the network weights
		trainable_vars_by_name = {var.name[len(scope_name):]: var
		                          for var in trainable_vars}
		return trainable_vars_by_name

# %%
tf.reset_default_graph()
X_state = tf.placeholder(tf.float32, shape=[None, input_height, input_width, input_channels])
# initialize the two Q network
online_q = DQN(state_size, action_size, learning_rate, 'online_q_network')
target_q = DQN(state_size, action_size, learning_rate, 'target_q_network')
# get the output and weights from online q network
online_q_values = online_q.get_outputs()
online_q_weights = online_q.get_weights(scope_name='online_q_network')
# # get the output and weights from target q network
target_q_values = target_q.get_outputs()
target_q_weights = target_q.get_weights(scope_name='target_q_network')
# define the operation to copy the online network weights to target_q_network weights
copy_ops = [target_var.assign(online_q_weights[var_name]) for var_name, target_var in target_q_weights.items()]
#
copy_online_to_target = tf.group(*copy_ops)

with tf.variable_scope("train"):
	# define training operation
	input_action = tf.placeholder(tf.int32, shape=[None])
	y = tf.placeholder(tf.float32, shape=[None, 1])
	# Get the Q values for the input_action
	q_value = tf.reduce_sum(online_q_values * tf.one_hot(input_action, action_size), axis=1, keepdims=True)
	# compute the error between lable y and q_value from online_q_network approximation
	# Note that lable y is computed using the target_q_network
	error = tf.abs(y - q_value)
	clipped_error = tf.clip_by_value(error, 0, 1)
	linear_error = 2 * (error - clipped_error)
	loss = tf.reduce_mean(tf.square(clipped_error) + linear_error)

	# global_step is used to keep track of number of training steps completed
	global_step = tf.Variable(0, trainable=False, name='global_step')
	optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate, decay=rmsprop_decay, momentum=0.0, epsilon=rmsprop_constant, name='RMSProp')
	# optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate, beta1=0.9, beta2=0.999, epsilon=1e-08,
	#                                    use_locking=False, name='Adam')
	training_op = optimizer.minimize(loss, global_step=global_step)

init = tf.global_variables_initializer()
saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From <ipython-input-7-da558a11b751>:40: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From <ipython-input-7-da558a11b751>:68: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# reduced replay buffer size (see if it can avoid the RAM crashing issue)
replay_memory_size = 400000

# replay_memory = deque([],maxlen=replay_memory_size)
class ReplayBuffer:
	def __init__(self, maxlen):
		self.maxlen = maxlen
		self.buf = np.empty(shape=maxlen, dtype=np.object)
		self.index = 0
		self.length = 0

	def append(self, data):
		self.buf[self.index] = data
		self.length = min(self.length + 1, self.maxlen)
		self.index = (self.index + 1) % self.maxlen

	def sample(self, batch_size):
		# sample without replacement
		indices = np.random.permutation(self.length)[:batch_size]
		return self.buf[indices]

# create an instance of ReplayBuffer
replay_buffer = ReplayBuffer(replay_memory_size)

def sample_replay_buffer(batch_size):
	cols = [[], [], [], [], []]  # state, action, reward, next_state, continue
	for memory in replay_buffer.sample(batch_size):
		for col, value in zip(cols, memory):
			col.append(value)
	cols = [np.array(col) for col in cols]
	return cols[0], cols[1], cols[2].reshape(-1, 1), cols[3], cols[4].reshape(-1, 1)

eps_min = 0.1
eps_max = 1.0
eps_decay_steps = 2000000
def epsilon_greedy(q_values, step):
    # Note: we gradually decrease epsilon, we explore more in the beginning, less towards later
    epsilon = max(eps_min, eps_max-(eps_max-eps_min)*step/eps_decay_steps)
    if np.random.rand()<epsilon:
        return np.random.randint(n_outputs)
    else:
        return np.argmax(q_values)

# %%
# checkpoint path
checkpoint_path="/content/gdrive/MyDrive/breakout_run10.ckpt"
# This is the number of training steps
n_steps = 4000000
# In the very beginning, first have 10000 samples in the replay buffer
training_start=10000
# Before each training step, we run 4 episodes and add those samples to replay buffer
training_interval=4
save_steps=1000
copy_steps = 1000 # reduced the copy_steps from 2500 to 1000, to enable more frequent updates of the network
discount_rate=0.99
skip_start=90
batch_size=50
iteration=0
done=True
# initialize the tracking statistics
total_max_q=-float('inf')
mean_reward=0
total_reward=0
game_length=0
game_counter=0

with tf.Session() as sess:
	if os.path.isfile(checkpoint_path + ".index"):
		saver.restore(sess, checkpoint_path)
	else:
		init.run()
		# to make sure they have the same values to begin with
		# otherwise, different seeds will result in different initialized network weights
		copy_online_to_target.run()
	# intialize replay buffer
	replay_buffer = ReplayBuffer(replay_memory_size)
	# initialize 2 lists to store the final training results
	final_each_episode_rwd = []
	final_mean_max_q = []
	# start training
	# Training loop :
	# (1) collect M data points, add to replay buffer (play 4 episodes of game, add those to replay buffer)
	# (2) copy online network parameter to target network
	# (3) sample a batch from replay buffer, do the online network update (batch size:50)
	while True:
		step = global_step.eval()
		# if global training steps have meet the maximum, we will stop training
		if step >= n_steps:
			break
		# One iteration is just one sample generation !!!
		iteration += 1
		if done:
			obs = env.reset()
			for skip in range(skip_start):  # skip the beginning of each game
				obs, reward, done, info = env.step(0)  # take action 0
			state = preprocess(obs)
		state = state.reshape(1, 80, 80, 1)
		state_to_rb = state.reshape(80, 80, 1)

		# online network evaluates what to do
		q_values = online_q_values.eval(feed_dict={online_q.inputs: state})
		# q_values returns array of 4 values corresponding to 4 actions
		# for each step in the game, we record the max of q_values
		action = epsilon_greedy(q_values, step)

		# online network plays
		obs, reward, done, info = env.step(action)
		next_state = preprocess(obs)
		next_state = next_state.reshape(1, 80, 80, 1)
		next_state_to_rb = next_state.reshape(80, 80, 1)

		# Add this sample to the replay buffer
		replay_buffer.append((state_to_rb, action, reward, next_state_to_rb, 1.0 - done))
		# pass "next_state" to "state"
		state = next_state
		state_to_rb = next_state_to_rb

		# compute statistics to track training progress
		# track the maximum episode reward obtained so far, and the average episode reward
		total_reward += reward
		total_max_q += q_values.max()
		game_length += 1
		if done:
			game_counter += 1
			mean_max_q = total_max_q / game_length
			new_episode_reward = total_reward
			# print statistics after each game
			print("Iteration %d\tTraining step %d/%d  Mean Max Q %f last_episode_reward %d Game counts %d" % (
			iteration, step, n_steps, mean_max_q, total_reward, game_counter))
			# append the results to the final output
			final_each_episode_rwd.append(new_episode_reward)
			final_mean_max_q.append(mean_max_q)
			# reset the counters
			total_max_q = 0.0
			game_length = 0
			total_reward = 0

		# if number of samples are less than training_start(10000), or it is not a multiple of 4, we do not train
		if iteration < training_start or iteration % training_interval != 0:
			continue

		#     if iteration % 100 == 0: # print stats every 100 training steps
		#       print("Iteration %d\tTraining step %d/%d  Mean Max Q %f episode total reward %d average episode reward
		#       %f Game counts %d" %(iteration, step, n_steps, mean_max_q, total_reward, game_counter))
		#       print("Iteration %d\tTraining step %d/%d  Mean Max Q %f avg_rwds_30_episode %f  Game counts %d" %(
		#       iteration, step, n_steps, mean_max_q, avg_30_episode_rwd, game_counter))
		# otherwise, if iteration is more than 10,000 and it is a multiple of 4, we will update the network
		# result=sample_replay_buffer(batch_size)
		X_state_val, X_action_val, rewards, X_next_state_val, continues = sample_replay_buffer(batch_size)
		#
		next_q_values = target_q_values.eval(
			feed_dict={target_q.inputs: X_next_state_val}
		)
		max_next_q_values = np.max(next_q_values, axis=1, keepdims=True)
		y_val = rewards + continues * discount_rate * max_next_q_values

		# train online q network
		_, loss_val = sess.run([training_op, loss],
		                       feed_dict={online_q.inputs: X_state_val, input_action: X_action_val, y: y_val})

		# copy online q network to target network
		if step % copy_steps == 0:
			copy_online_to_target.run()

		# save dqn regularly
		if step % save_steps == 0:
			saver.save(sess, checkpoint_path)

			# save output to text
			#       with open('breakout_run1_cont_avg_30_episode_reward.txt', 'w') as file:
			#           file.write('%s\n' % final_avg30_epi_rwd)
			with open('/content/gdrive/MyDrive/breakout_run10_mean_max_q.txt', 'w') as file:
				file.write('%s\n' % final_mean_max_q)
# Out:
# Iteration 238	Training step 0/4000000  Mean Max Q -inf last_episode_reward 1 Game counts 1
# Iteration 431	Training step 0/4000000  Mean Max Q 0.191218 last_episode_reward 0 Game counts 2
# Iteration 598	Training step 0/4000000  Mean Max Q 0.191371 last_episode_reward 0 Game counts 3
# Iteration 884	Training step 0/4000000  Mean Max Q 0.192711 last_episode_reward 2 Game counts 4
# Iteration 1170	Training step 0/4000000  Mean Max Q 0.192910 last_episode_reward 2 Game counts 5
# Iteration 1382	Training step 0/4000000  Mean Max Q 0.180967 last_episode_reward 1 Game counts 6
# Iteration 1663	Training step 0/4000000  Mean Max Q 0.193801 last_episode_reward 2 Game counts 7
# Iteration 2008	Training step 0/4000000  Mean Max Q 0.194291 last_episode_reward 3 Game counts 8
# Iteration 2218	Training step 0/4000000  Mean Max Q 0.187163 last_episode_reward 1 Game counts 9
# Iteration 2531	Training step 0/4000000  Mean Max Q 0.192873 last_episode_reward 2 Game counts 10
# Iteration 2823	Training step 0/4000000  Mean Max Q 0.192610 last_episode_reward 2 Game counts 11
# Iteration 3063	Training step 0/4000000  Mean Max Q 0.193966 last_episode_reward 1 Game counts 12
# Iteration 3337	Training step 0/4000000  Mean Max Q 0.202309 last_episode_reward 2 Game counts 13
# Iteration 3520	Training step 0/4000000  Mean Max Q 0.190866 last_episode_reward 0 Game counts 14
# Iteration 3765	Training step 0/4000000  Mean Max Q 0.188388 last_episode_reward 1 Game counts 15
# Iteration 4025	Training step 0/4000000  Mean Max Q 0.191220 last_episode_reward 2 Game counts 16
# Iteration 4256	Training step 0/4000000  Mean Max Q 0.189229 last_episode_reward 1 Game counts 17
# Iteration 4539	Training step 0/4000000  Mean Max Q 0.186791 last_episode_reward 2 Game counts 18
# Iteration 4778	Training step 0/4000000  Mean Max Q 0.191728 last_episode_reward 1 Game counts 19
# Iteration 5141	Training step 0/4000000  Mean Max Q 0.192895 last_episode_reward 4 Game counts 20
# Iteration 5376	Training step 0/4000000  Mean Max Q 0.200549 last_episode_reward 1 Game counts 21
# Iteration 5627	Training step 0/4000000  Mean Max Q 0.193107 last_episode_reward 1 Game counts 22
# Iteration 6008	Training step 0/4000000  Mean Max Q 0.199327 last_episode_reward 3 Game counts 23
# Iteration 6247	Training step 0/4000000  Mean Max Q 0.193277 last_episode_reward 1 Game counts 24
# Iteration 6554	Training step 0/4000000  Mean Max Q 0.199355 last_episode_reward 2 Game counts 25
# Iteration 6913	Training step 0/4000000  Mean Max Q 0.196218 last_episode_reward 3 Game counts 26
# Iteration 7253	Training step 0/4000000  Mean Max Q 0.193014 last_episode_reward 3 Game counts 27
# Iteration 7558	Training step 0/4000000  Mean Max Q 0.192553 last_episode_reward 2 Game counts 28
# Iteration 7827	Training step 0/4000000  Mean Max Q 0.194029 last_episode_reward 2 Game counts 29
# Iteration 7999	Training step 0/4000000  Mean Max Q 0.191392 last_episode_reward 0 Game counts 30
# Iteration 8188	Training step 0/4000000  Mean Max Q 0.191123 last_episode_reward 0 Game counts 31
# Iteration 8498	Training step 0/4000000  Mean Max Q 0.184170 last_episode_reward 3 Game counts 32
# Iteration 8801	Training step 0/4000000  Mean Max Q 0.194619 last_episode_reward 2 Game counts 33
# Iteration 9069	Training step 0/4000000  Mean Max Q 0.188184 last_episode_reward 1 Game counts 34
# Iteration 9231	Training step 0/4000000  Mean Max Q 0.190998 last_episode_reward 0 Game counts 35
# Iteration 9469	Training step 0/4000000  Mean Max Q 0.192435 last_episode_reward 1 Game counts 36
# Iteration 9649	Training step 0/4000000  Mean Max Q 0.191669 last_episode_reward 0 Game counts 37
# Iteration 9814	Training step 0/4000000  Mean Max Q 0.191982 last_episode_reward 0 Game counts 38
# Iteration 10049	Training step 13/4000000  Mean Max Q 0.193019 last_episode_reward 1 Game counts 39
# Iteration 10404	Training step 101/4000000  Mean Max Q 0.198893 last_episode_reward 4 Game counts 40
# Iteration 10573	Training step 144/4000000  Mean Max Q 0.201960 last_episode_reward 0 Game counts 41
# Iteration 10748	Training step 187/4000000  Mean Max Q 0.203618 last_episode_reward 0 Game counts 42
# Iteration 10981	Training step 246/4000000  Mean Max Q 0.202817 last_episode_reward 1 Game counts 43
# Iteration 11163	Training step 291/4000000  Mean Max Q 0.198481 last_episode_reward 0 Game counts 44
# Iteration 11497	Training step 375/4000000  Mean Max Q 0.199897 last_episode_reward 3 Game counts 45
# Iteration 20036	Training step 2509/4000000  Mean Max Q 0.233716 last_episode_reward 2 Game counts 77
# Iteration 20216	Training step 2554/4000000  Mean Max Q 0.225184 last_episode_reward 0 Game counts 78
# Iteration 20451	Training step 2613/4000000  Mean Max Q 0.230897 last_episode_reward 1 Game counts 79
# Iteration 20757	Training step 2690/4000000  Mean Max Q 0.231062 last_episode_reward 2 Game counts 80
# Iteration 21136	Training step 2784/4000000  Mean Max Q 0.226951 last_episode_reward 4 Game counts 81
# Iteration 21429	Training step 2858/4000000  Mean Max Q 0.229470 last_episode_reward 2 Game counts 82
# Iteration 21678	Training step 2920/4000000  Mean Max Q 0.226619 last_episode_reward 1 Game counts 83
# Iteration 21849	Training step 2963/4000000  Mean Max Q 0.233418 last_episode_reward 0 Game counts 84
# Iteration 22113	Training step 3029/4000000  Mean Max Q 0.235541 last_episode_reward 2 Game counts 85
# Iteration 22453	Training step 3114/4000000  Mean Max Q 0.233796 last_episode_reward 3 Game counts 86
# Iteration 22822	Training step 3206/4000000  Mean Max Q 0.235605 last_episode_reward 3 Game counts 87
# Iteration 23133	Training step 3284/4000000  Mean Max Q 0.238535 last_episode_reward 2 Game counts 88
# Iteration 23401	Training step 3351/4000000  Mean Max Q 0.233334 last_episode_reward 2 Game counts 89
# Iteration 23627	Training step 3407/4000000  Mean Max Q 0.239300 last_episode_reward 1 Game counts 90
# Iteration 23880	Training step 3470/4000000  Mean Max Q 0.232441 last_episode_reward 2 Game counts 91
# Iteration 24049	Training step 3513/4000000  Mean Max Q 0.230931 last_episode_reward 0 Game counts 92
# Iteration 24269	Training step 3568/4000000  Mean Max Q 0.236125 last_episode_reward 1 Game counts 93
# Iteration 24544	Training step 3636/4000000  Mean Max Q 0.231731 last_episode_reward 2 Game counts 94
# Iteration 24865	Training step 3717/4000000  Mean Max Q 0.230132 last_episode_reward 3 Game counts 95
# Iteration 25091	Training step 3773/4000000  Mean Max Q 0.238664 last_episode_reward 1 Game counts 96
# Iteration 25425	Training step 3857/4000000  Mean Max Q 0.236462 last_episode_reward 3 Game counts 97
# Iteration 25764	Training step 3941/4000000  Mean Max Q 0.231196 last_episode_reward 3 Game counts 98
# Iteration 25929	Training step 3983/4000000  Mean Max Q 0.230232 last_episode_reward 0 Game counts 99
# Iteration 26140	Training step 4035/4000000  Mean Max Q 0.224823 last_episode_reward 1 Game counts 100
# Iteration 26434	Training step 4109/4000000  Mean Max Q 0.232587 last_episode_reward 2 Game counts 101
# Iteration 26702	Training step 4176/4000000  Mean Max Q 0.239141 last_episode_reward 2 Game counts 102
# Iteration 26875	Training step 4219/4000000  Mean Max Q 0.226588 last_episode_reward 0 Game counts 103
# Iteration 27157	Training step 4290/4000000  Mean Max Q 0.239170 last_episode_reward 2 Game counts 104
# Iteration 27416	Training step 4354/4000000  Mean Max Q 0.235120 last_episode_reward 2 Game counts 105
# Iteration 27777	Training step 4445/4000000  Mean Max Q 0.234598 last_episode_reward 3 Game counts 106
# Iteration 27961	Training step 4491/4000000  Mean Max Q 0.232805 last_episode_reward 0 Game counts 107
# Iteration 28351	Training step 4588/4000000  Mean Max Q 0.228501 last_episode_reward 3 Game counts 108
# Iteration 28516	Training step 4629/4000000  Mean Max Q 0.227397 last_episode_reward 0 Game counts 109
# Iteration 28815	Training step 4704/4000000  Mean Max Q 0.226250 last_episode_reward 2 Game counts 110
# Iteration 28984	Training step 4746/4000000  Mean Max Q 0.225858 last_episode_reward 0 Game counts 111
# Iteration 29148	Training step 4787/4000000  Mean Max Q 0.231639 last_episode_reward 0 Game counts 112
# Iteration 29452	Training step 4863/4000000  Mean Max Q 0.228251 last_episode_reward 2 Game counts 113
# Iteration 29744	Training step 4936/4000000  Mean Max Q 0.235568 last_episode_reward 2 Game counts 114
# Iteration 29949	Training step 4988/4000000  Mean Max Q 0.227524 last_episode_reward 1 Game counts 115
# Iteration 30261	Training step 5066/4000000  Mean Max Q 0.231503 last_episode_reward 2 Game counts 116
# Iteration 30487	Training step 5122/4000000  Mean Max Q 0.240279 last_episode_reward 1 Game counts 117
# Iteration 30655	Training step 5164/4000000  Mean Max Q 0.225835 last_episode_reward 0 Game counts 118
# Iteration 30820	Training step 5205/4000000  Mean Max Q 0.230857 last_episode_reward 0 Game counts 119
# Iteration 31246	Training step 5312/4000000  Mean Max Q 0.229670 last_episode_reward 5 Game counts 120
# Iteration 31490	Training step 5373/4000000  Mean Max Q 0.233820 last_episode_reward 1 Game counts 121
# Iteration 31700	Training step 5425/4000000  Mean Max Q 0.231290 last_episode_reward 1 Game counts 122
# Iteration 31949	Training step 5488/4000000  Mean Max Q 0.227646 last_episode_reward 1 Game counts 123
# Iteration 32165	Training step 5542/4000000  Mean Max Q 0.231592 last_episode_reward 1 Game counts 124
# Iteration 32452	Training step 5613/4000000  Mean Max Q 0.240339 last_episode_reward 2 Game counts 125
# Iteration 32706	Training step 5677/4000000  Mean Max Q 0.228002 last_episode_reward 2 Game counts 126
# Iteration 33013	Training step 5754/4000000  Mean Max Q 0.232126 last_episode_reward 2 Game counts 127
# Iteration 33254	Training step 5814/4000000  Mean Max Q 0.232530 last_episode_reward 1 Game counts 128
# Iteration 33502	Training step 5876/4000000  Mean Max Q 0.225557 last_episode_reward 1 Game counts 129
# Iteration 33769	Training step 5943/4000000  Mean Max Q 0.241798 last_episode_reward 2 Game counts 130
# Iteration 33950	Training step 5988/4000000  Mean Max Q 0.227119 last_episode_reward 0 Game counts 131
# Iteration 34119	Training step 6030/4000000  Mean Max Q 0.233111 last_episode_reward 0 Game counts 132
# Iteration 34291	Training step 6073/4000000  Mean Max Q 0.239300 last_episode_reward 0 Game counts 133
# Iteration 34566	Training step 6142/4000000  Mean Max Q 0.244037 last_episode_reward 2 Game counts 134
# Iteration 34752	Training step 6188/4000000  Mean Max Q 0.236231 last_episode_reward 0 Game counts 135
# Iteration 34928	Training step 6232/4000000  Mean Max Q 0.237458 last_episode_reward 0 Game counts 136
# Iteration 35199	Training step 6300/4000000  Mean Max Q 0.232188 last_episode_reward 2 Game counts 137
# Iteration 35426	Training step 6357/4000000  Mean Max Q 0.239136 last_episode_reward 1 Game counts 138
# Iteration 35634	Training step 6409/4000000  Mean Max Q 0.236272 last_episode_reward 1 Game counts 139
# Iteration 35874	Training step 6469/4000000  Mean Max Q 0.240042 last_episode_reward 1 Game counts 140
# Iteration 36093	Training step 6524/4000000  Mean Max Q 0.233697 last_episode_reward 1 Game counts 141
# Iteration 36452	Training step 6613/4000000  Mean Max Q 0.247091 last_episode_reward 3 Game counts 142
# Iteration 36821	Training step 6706/4000000  Mean Max Q 0.252230 last_episode_reward 4 Game counts 143
# Iteration 37110	Training step 6778/4000000  Mean Max Q 0.245569 last_episode_reward 2 Game counts 144
# Iteration 37297	Training step 6825/4000000  Mean Max Q 0.243781 last_episode_reward 0 Game counts 145
# Iteration 37634	Training step 6909/4000000  Mean Max Q 0.241817 last_episode_reward 3 Game counts 146
# Iteration 37980	Training step 6995/4000000  Mean Max Q 0.254983 last_episode_reward 3 Game counts 147
# Iteration 38273	Training step 7069/4000000  Mean Max Q 0.255301 last_episode_reward 2 Game counts 148
# Iteration 38492	Training step 7123/4000000  Mean Max Q 0.268819 last_episode_reward 1 Game counts 149
# Iteration 38839	Training step 7210/4000000  Mean Max Q 0.265688 last_episode_reward 3 Game counts 150
# Iteration 39067	Training step 7267/4000000  Mean Max Q 0.252063 last_episode_reward 1 Game counts 151
# Iteration 39265	Training step 7317/4000000  Mean Max Q 0.252739 last_episode_reward 1 Game counts 152
# Iteration 39544	Training step 7386/4000000  Mean Max Q 0.264997 last_episode_reward 2 Game counts 153
# Iteration 39818	Training step 7455/4000000  Mean Max Q 0.265197 last_episode_reward 2 Game counts 154
# Iteration 39981	Training step 7496/4000000  Mean Max Q 0.259577 last_episode_reward 0 Game counts 155
# Iteration 40219	Training step 7555/4000000  Mean Max Q 0.262704 last_episode_reward 1 Game counts 156
# Iteration 40395	Training step 7599/4000000  Mean Max Q 0.257177 last_episode_reward 0 Game counts 157
# Iteration 40605	Training step 7652/4000000  Mean Max Q 0.255785 last_episode_reward 1 Game counts 158
# Iteration 40887	Training step 7722/4000000  Mean Max Q 0.261507 last_episode_reward 2 Game counts 159
# Iteration 41091	Training step 7773/4000000  Mean Max Q 0.253865 last_episode_reward 1 Game counts 160
# Iteration 41271	Training step 7818/4000000  Mean Max Q 0.254009 last_episode_reward 0 Game counts 161
# Iteration 41576	Training step 7894/4000000  Mean Max Q 0.267311 last_episode_reward 2 Game counts 162
# Iteration 41845	Training step 7962/4000000  Mean Max Q 0.267487 last_episode_reward 2 Game counts 163
# Iteration 42224	Training step 8056/4000000  Mean Max Q 0.261714 last_episode_reward 4 Game counts 164
# Iteration 42527	Training step 8132/4000000  Mean Max Q 0.262904 last_episode_reward 2 Game counts 165
# Iteration 42847	Training step 8212/4000000  Mean Max Q 0.254519 last_episode_reward 2 Game counts 166
# Iteration 43151	Training step 8288/4000000  Mean Max Q 0.275022 last_episode_reward 2 Game counts 167
# Iteration 111988	Training step 25497/4000000  Mean Max Q 0.308650 last_episode_reward 0 Game counts 442
# Iteration 112270	Training step 25568/4000000  Mean Max Q 0.388272 last_episode_reward 2 Game counts 443
# Iteration 112438	Training step 25610/4000000  Mean Max Q 0.310820 last_episode_reward 0 Game counts 444
# Iteration 112613	Training step 25654/4000000  Mean Max Q 0.307994 last_episode_reward 0 Game counts 445
# Iteration 112906	Training step 25727/4000000  Mean Max Q 0.400191 last_episode_reward 2 Game counts 446
# Iteration 113191	Training step 25798/4000000  Mean Max Q 0.380162 last_episode_reward 2 Game counts 447
# Iteration 113407	Training step 25852/4000000  Mean Max Q 0.307146 last_episode_reward 1 Game counts 448
# Iteration 113698	Training step 25925/4000000  Mean Max Q 0.384997 last_episode_reward 2 Game counts 449
# Iteration 113988	Training step 25997/4000000  Mean Max Q 0.361848 last_episode_reward 2 Game counts 450
# Iteration 114292	Training step 26073/4000000  Mean Max Q 0.410204 last_episode_reward 2 Game counts 451
# Iteration 114538	Training step 26135/4000000  Mean Max Q 0.368430 last_episode_reward 1 Game counts 452
# Iteration 114752	Training step 26188/4000000  Mean Max Q 0.367504 last_episode_reward 1 Game counts 453
# Iteration 114996	Training step 26249/4000000  Mean Max Q 0.378043 last_episode_reward 1 Game counts 454
# Iteration 115213	Training step 26304/4000000  Mean Max Q 0.377202 last_episode_reward 1 Game counts 455
# Iteration 115468	Training step 26367/4000000  Mean Max Q 0.302145 last_episode_reward 2 Game counts 456
# Iteration 115709	Training step 26428/4000000  Mean Max Q 0.376366 last_episode_reward 1 Game counts 457
# Iteration 115973	Training step 26494/4000000  Mean Max Q 0.401070 last_episode_reward 2 Game counts 458
# Iteration 116230	Training step 26558/4000000  Mean Max Q 0.410807 last_episode_reward 2 Game counts 459
# Iteration 116412	Training step 26603/4000000  Mean Max Q 0.314629 last_episode_reward 0 Game counts 460
# Iteration 116624	Training step 26656/4000000  Mean Max Q 0.358655 last_episode_reward 1 Game counts 461
# Iteration 116835	Training step 26709/4000000  Mean Max Q 0.355023 last_episode_reward 1 Game counts 462
# Iteration 117015	Training step 26754/4000000  Mean Max Q 0.312858 last_episode_reward 0 Game counts 463
# Iteration 117325	Training step 26832/4000000  Mean Max Q 0.386268 last_episode_reward 3 Game counts 464
# Iteration 117555	Training step 26889/4000000  Mean Max Q 0.369856 last_episode_reward 1 Game counts 465
# Iteration 117833	Training step 26959/4000000  Mean Max Q 0.406709 last_episode_reward 2 Game counts 466
# Iteration 118142	Training step 27036/4000000  Mean Max Q 0.397135 last_episode_reward 2 Game counts 467
# Iteration 118332	Training step 27083/4000000  Mean Max Q 0.333704 last_episode_reward 0 Game counts 468
# Iteration 118519	Training step 27130/4000000  Mean Max Q 0.335581 last_episode_reward 0 Game counts 469
# ...
# Iteration 1028022	Training step 254506/4000000  Mean Max Q 1.204270 last_episode_reward 3 Game counts 4128
# Iteration 1028197	Training step 254550/4000000  Mean Max Q 1.005771 last_episode_reward 0 Game counts 4129
# Iteration 1028481	Training step 254621/4000000  Mean Max Q 0.994870 last_episode_reward 2 Game counts 4130
